# %% [markdown]
# **CNN (MNIST DIGIT DATASET)**

# %% [markdown]
# Insert Code wherever represented with "#***************#"

# %% [markdown]
# # Importing Libraries

# %%
import tensorflow as tf
# import cv2
import numpy as np
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential , load_model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model
# Out:
# 2024-11-28 14:29:28.288698: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-28 14:29:28.292487: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-28 14:29:28.302173: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1732784368.319546  271019 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1732784368.324852  271019 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-28 14:29:28.343340: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Data Preprocessing

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(60000,28,28)

x_test = x_test.reshape(x_test.shape[0],28,28)

input_shape = (28,28,1)

y_train = tf.keras.utils.to_categorical(y_train,10)

y_test = tf.keras.utils.to_categorical(y_test,10)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

for i in range(10):
  plt.imshow(x_train[i])
  plt.subplot(5,2,i+1)

# %% [markdown]
# # Build CNN Model

# %%
x_train /= 255
x_test /=255
model = None  #Initialize model here

'''
Define batch size of 64 , 
No of classes (interpret from data)
Train for 5 epochs

'''
batch_size = 64
num_classes = y_train.shape[1]
epochs = 5

def build_model(optimizer): 

    '''
    Define a sequential model with categorical cross entropy as loss function consisting
    2 convolution and 2 pooling layers with relu as activation function followed by
    droput -> flatten -> dense -> dropout -> dense
    
    Convolution layer - (kernel size = (3*3))
    Pooling layer - (pool size = (2*2))
    
    '''

    #****** INSERT MODEL CODE HERE ******
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

    return model 

#**** call build model with ADAM and ADAGRAD Optimizer ****

model = build_model('adam')
plot_model(model, to_file="mnist model"+ '.jpg', show_shapes=True)
hist=model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(x_test,y_test))
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.
# /home/ninet33n/Desktop/clg/temp/.venv/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 2024-11-28 14:31:54.090486: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 188160000 exceeds 10% of free system memory.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 30s 28ms/step - accuracy: 0.3030 - loss: 1.8903 - val_accuracy: 0.8880 - val_loss: 0.3931
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 27s 29ms/step - accuracy: 0.8213 - loss: 0.5614 - val_accuracy: 0.9301 - val_loss: 0.2393
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 29ms/step - accuracy: 0.8767 - loss: 0.3995 - val_accuracy: 0.9479 - val_loss: 0.1755
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 28s 29ms/step - accuracy: 0.9028 - loss: 0.3154 - val_accuracy: 0.9581 - val_loss: 0.1386
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 27s 29ms/step - accuracy: 0.9177 - loss: 0.2733 - val_accuracy: 0.9647 - val_loss: 0.1163

# %%
y1=hist.history['accuracy']
y2=hist.history['val_accuracy']
plt.plot(y1)
plt.plot(y2)

# %% [markdown]
# # Predict Image

# %%
# keras.models.save_model(model, "mnist.h5", save_format="h5")

def predict_image(model, img):

  '''
  Reshape the image into (1,28,28)
  predict the answer and print it

  '''
  #**** Insert code here ****
  img = img.reshape(1, 28, 28, 1)
  prediction = model.predict(img)
  print("Predicted digit:", prediction.argmax())


# m = load_model('/content/mnist.h5')
predict_image(model, x_test[7])
plt.imshow(x_test[7],cmap='gray')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Predicted digit: 9
